# %%
import pandas as pd
df = pd.read_csv("preferred_basin.csv")
print(df.describe())
print(df.columns)
# Out:
#        basin_type  dist_to_1  dist_to_2  dist_to_3          area1  \
# count   88.000000  88.000000  62.000000  88.000000      88.000000
# mean     1.295455   0.001066   0.335405   0.966859   29624.031316
# std      0.458861   0.006494   1.221401   1.570002  122493.228714
# min      1.000000   0.000000   0.000000   0.000000       0.034256
# 25%      1.000000   0.000000   0.000000   0.000000      44.466141
# 50%      1.000000   0.000000   0.000000   0.161756     569.745678
# 75%      2.000000   0.000000   0.019953   1.313990    4051.349414
# max      2.000000   0.056390   8.884047   6.292371  765620.096296
#
#                area2         area3
# count      62.000000     88.000000
# mean    12716.879661   3703.187680
# std     47448.165553   8516.937081
# min        11.493594      1.431537
# 25%       109.796519     32.908541
# 50%      1044.880642    260.468466
# 75%      4365.663428   2360.134406
# max    307042.418437  46847.376561
# ...

# %%
print(f"flag_area: {df[df.flag_area == True].flag_area.shape[0]}")
print(f"flag_b1_b2: {df[df.flag_basin1_over_basin2 == True].flag_basin1_over_basin2.shape[0]}")
print(f"flag_not_contained: {df[df.flag_not_contained == True].flag_not_contained.shape[0]}")
print(f"flag_river: {df[df.flag_river == True].flag_river.shape[0]}")
print(f"review: {df[df.reviewed == True].reviewed.shape[0]}")
# Out:
# flag_area: 5
# flag_b1_b2: 36
# flag_not_contained: 2
# flag_river: 3
# review: 0

# %%
metadata = pd.read_csv("preferred_basin_archive.csv")
metadata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   site_uid                 88 non-null     str
#  1   basin_name               88 non-null     str
#  2   basin_type               88 non-null     int64
#  3   dist_to_1                88 non-null     float64
#  4   dist_to_2                62 non-null     float64
#  5   dist_to_3                88 non-null     float64
#  6   area1                    88 non-null     float64
#  7   area2                    62 non-null     float64
#  8   area3                    88 non-null     float64
#  9   selection_mode           88 non-null     str
#  10  reviewed                 88 non-null     bool
#  11  flag_area                88 non-null     bool
#  12  flag_river               88 non-null     bool
#  13  flag_not_contained       88 non-null     bool
# ...

# %%
metadata.basin_type.
# Out:
# np.int64(88)
