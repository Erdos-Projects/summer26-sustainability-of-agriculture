# %%
import pandas as pd

df = pd.read_csv("Iowa weather by region.csv", nrows=10)
print(df.head(10))
# Out:
#                                                                                                           Table 1
# station station_name                          lat           lon            day        doy high low precip    snow
# IAC009  Iowa - Southeast Climate Division     41.0387041389 -91.8205634896 YYYY-01-DD 1   47   25  0            0
# IAC008  Iowa - South Central Climate Division 41.0467323739 -93.4940760185 YYYY-01-DD 1   50   24  0            0
# IAC001  Iowa - Northwest Climate Division     43.027020875  -95.4945087229 YYYY-01-DD 1   48   19  0            0
# IAC006  Iowa - East Central Climate Division  41.897557125  -91.253429866  YYYY-01-DD 1   43   22  0            0
# IAC002  Iowa - North Central Climate Division 43.0498599625 -93.4890263095 YYYY-01-DD 1   42   21  0            0
# IAC004  Iowa - West Central Climate Division  42.0398027871 -95.2599670554 YYYY-01-DD 1   49   22  0            0
# ...
