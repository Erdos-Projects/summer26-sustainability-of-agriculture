# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

import sys
sys.path.insert(0, "../")
from data import get_data, get_site_ids

# %%
from statsmodels.tsa.stattools import acf
site_uid = "WQS0071"

# uncomment to create 
# rain and water autocorrelation
# plots

"""
def acf_plot(site_uid, ax):
    data = get_data(site_uid=site_uid)
    water = data.water.resample("1D").max()["nitrate_con"]
    rain = data.rain.groupby(["date"])[["precip_in_1d"]].sum().reset_index().set_index("date")
    sm.graphics.tsa.plot_acf(
        water.values, 
        lags=50,ax=ax, 
        missing="conservative", 
        label="water_nitrate",
        color="tab:orange",
        vlines_kwargs={"colors": "tab:orange"},)
    sm.graphics.tsa.plot_acf(
        rain.values, 
        lags=50,ax=ax, 
        missing="conservative", 
        label="rain",
        color="tab:blue",
        vlines_kwargs={"colors": "tab:blue"},)
    ax.set_title(f"Autocorrelation {site_uid}")
    ax.set_ylim(-1.1, 1.1)
    ax.set_ylim(-1.1, 1.1)

fig, axes = plt.subplots(17, 5, figsize=(40, 80))
axes = axes.flatten()
for i,site in enumerate(get_site_ids()):
    if i % 5 ==0:
        print(f"{i} sites processed")
    acf_plot(site, axes[i])
    
plt.show()
"""
# Out:
# '\ndef acf_plot(site_uid, ax):\n    data = get_data(site_uid=site_uid)\n    water = data.water.resample("1D").max()["nitrate_con"]\n    rain = data.rain.groupby(["date"])[["precip_in_1d"]].sum().reset_index().set_index("date")\n    sm.graphics.tsa.plot_acf(\n        water.values, \n        lags=50,ax=ax, \n        missing="conservative", \n        label="water_nitrate",\n        color="tab:orange",\n        vlines_kwargs={"colors": "tab:orange"},)\n    sm.graphics.tsa.plot_acf(\n        rain.values, \n        lags=50,ax=ax, \n        missing="conservative", \n        label="rain",\n        color="tab:blue",\n        vlines_kwargs={"colors": "tab:blue"},)\n    ax.set_title(f"Autocorrelation {site_uid}")\n    ax.set_ylim(-1.1, 1.1)\n    ax.set_ylim(-1.1, 1.1)\n\nfig, axes = plt.subplots(17, 5, figsize=(40, 80))\naxes = axes.flatten()\nfor i,site in enumerate(get_site_ids()):\n    if i % 5 ==0:\n        print(f"{i} sites processed")\n    acf_plot(site, axes[i])\n\nplt.show()\n'

# %%
import statsmodels.tsa.api as sm
from statsforecast.models import AutoARIMA
from statsforecast.arima import arima_string

site_uid = "WQS0048"
data = get_data(site_uid=site_uid)
water = data.water["nitrate_con"].resample("1D").max().dropna()
rain = data.rain.groupby(["date"])[["precip_in_1d"]].sum().reset_index().set_index("date")
print(rain.values)
m = AutoARIMA().fit(rain.values[:,0])
print(arima_string(m.model_))
# Out:
# [[ 0.    0.   26.05 ...  0.    1.15  1.06]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[88], line 10
#       6 data = get_data(site_uid=site_uid)
#       7 water = data.water["nitrate_con"].resample("1D").max().dropna()
#       8 rain = data.rain.groupby(["date"])[["precip_in_1d"]].sum().reset_index().set_index("date")
#       9 print(rain.values.reshape(1,-1))
# ---> 10 m = AutoARIMA().fit(rain.values)
#      11 print(arima_string(m.model_))
#
# File ~/miniconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/statsforecast/models.py:357, in AutoARIMA.fit(self, y, X)
#     355 y = _ensure_float(y)
#     356 with np.errstate(invalid="ignore"):
# --> 357     self.model_ = auto_arima_f(
#     358         x=y,
#     359         d=self.d,
#     360         D=self.D,
#     361         max_p=self.max_p,
#     362         max_q=self.max_q,
#     363         max_P=self.max_P,
#     364         max_Q=self.max_Q,
#     365         max_order=self.max_order,
#     366         max_d=self.max_d,
#     367         max_D=self.max_D,
#     368         start_p=self.start_p,
#     369         start_q=self.start_q,
#     370         start_P=self.start_P,
#     371         start_Q=self.start_Q,
#     372         stationary=self.stationary,
#     373         seasonal=self.seasonal,
#     374         ic=self.ic,
#     375         stepwise=self.stepwise,
#     376         nmodels=self.nmodels,
#     377         trace=self.trace,
#     378         approximation=self.approximation,
#     379         method=self.method,
#     380         truncate=self.truncate,
#     381         xreg=X,
#     382         test=self.test,
#     383         test_kwargs=self.test_kwargs,
#     384         seasonal_test=self.seasonal_test,
#     385         seasonal_test_kwargs=self.seasonal_test_kwargs,
#     386         allowdrift=self.allowdrift,
#     387         allowmean=self.allowmean,
#     388         blambda=self.blambda,
#     389         biasadj=self.biasadj,
#     390         period=self.season_length,
#     391     )
#     393 self._store_cs(y=y, X=X)
#     394 return self
#
# File ~/miniconda3/envs/erdos_ds_environment/lib/python3.12/site-packages/statsforecast/arima.py:1401, in auto_arima_f(x, d, D, max_p, max_q, max_P, max_Q, max_order, max_d, max_D, start_p, start_q, start_P, start_Q, stationary, seasonal, ic, stepwise, nmodels, trace, approximation, method, truncate, xreg, test, test_kwargs, seasonal_test, seasonal_test_kwargs, allowdrift, allowmean, blambda, biasadj, period)
#    1399     approximation = len(x) > 150 or period > 12
#    1400 if x.ndim > 1:
# -> 1401     raise ValueError("auto_arima can only handle univariate time series")
#    1402 if test_kwargs is None:
#    1403     test_kwargs = {}
#
# ValueError: auto_arima can only handle univariate time series
